# %%
import argparse
import logging
import os, sys
from copy import copy
from datetime import datetime
from pathlib import Path
import time
from functools import partial
import gzip
from collections import defaultdict
from itertools import product
from functools import wraps

import dask.bag as db
import geopandas as gpd
import pandas as pd
import polars as pl
from tqdm import tqdm
from sqlalchemy.orm import Session
import networkx as nx
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.collections import LineCollection
from matplotlib import colors as mcolors, cm, gridspec, ticker, patches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import string
alphabet = string.ascii_lowercase

from pathlib import Path

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

sys.path.append("..")
sys.path.append("../..")


from database import get_engine
from utils.config_utils import load_config
from utils import plot_utils
from utils import graph_utils

# %% [markdown]
# # Data setup

# %%
plot_conf_file = Path(".").resolve().parent / "config/plots/swiss-data/plot_data.yml"
plot_conf = load_config(plot_conf_file)

dbconf_file = Path(".").resolve().parent / "config/database/database.yaml"
dbconf = load_config(dbconf_file)
ENGINE = get_engine(dbconf, pool_size=5, max_overflow=10)

OUTPATH = Path("/data/jenna/rain-cell-stats-analysis/figures/cell_histograms_v20250704")
OUTPATH.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Query data from database

# %%
# Extract raincells with statistics from the database
# and pivot the data to have a wide format with quantity.statistic as columns

START_DATE = datetime(2021, 5, 1)
END_DATE = datetime(2023, 10, 1)

FETCH_QUANTITIES = [
    "vil",
    "rate",
    "dist_from_radars",
]

SQL_QUERY = """

 SELECT cell."timestamp",
    cell.identifier,
    cell.method,
    -- cell.geometry,
    ST_Area(cell.geometry) / 1e6 AS area_km2,
    stats.quantity,
    stats.statistic,
    stats.value
   FROM raincells.stormcells cell
     JOIN raincells.stormcell_rasterstats stats ON cell.identifier = stats.identifier AND cell."timestamp" = stats."timestamp" AND cell.method::text = stats.method::text

    WHERE 1 = 1
    AND cell."timestamp" >= '{start_date}'
    AND cell."timestamp" <= '{end_date}'
    AND ((stats.quantity IN ({quantities})) or (stats.quantity like 'zdrcol%') or (stats.quantity like 'et45ml%'))
    AND stats.statistic IN ('mean', 'median', 'min', 'max', 'count')

"""

with Session(ENGINE) as session:
    query = SQL_QUERY.format(
        start_date=START_DATE.strftime("%Y-%m-%d %H:%M"),
        end_date=END_DATE.strftime("%Y-%m-%d %H:%M"),
        quantities=",".join([f"'{q}'" for q in FETCH_QUANTITIES]),
    )
    DATA = pl.read_database(
        query=query,
        connection=session.bind,
    )

    DATA = DATA.with_columns(pl.format("{}.{}", "quantity", "statistic").alias("on")).pivot(
        on="on",
        # index=["type", "t0_node", "timestamp", "level", "identifier", "method", "area", "event"],
        index=set(DATA.columns) - set(["quantity", "statistic", "value"]),
        values=["value"],
    )

# %%
DATA
# Out:
# shape: (735_207, 82)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ identifie ┆ area_km2  ┆ method    ┆ timestamp ┆ … ┆ zdrcol_cu ┆ zdrcol_cu ┆ zdrcol_cu ┆ zdrcol_c │
# │ r         ┆ ---       ┆ ---       ┆ ---       ┆   ┆ stom_filt ┆ stom_filt ┆ stom_filt ┆ ustom_fi │
# │ ---       ┆ f64       ┆ str       ┆ datetime[ ┆   ┆ .max      ┆ .median   ┆ .count    ┆ lt.mean  │
# │ i64       ┆           ┆           ┆ μs]       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ 10.002483 ┆ opencv_vi ┆ 2021-05-0 ┆ … ┆ 800.0     ┆ 800.0     ┆ 12.0      ┆ 800.0    │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 11:35:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 23.00571  ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 00:05:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 12.002979 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 00:10:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 14.003476 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 04:55:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 13.503352 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 05:00:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 87        ┆ 157.03897 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 7         ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 88        ┆ 55.513779 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 89        ┆ 45.011172 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 90        ┆ 40.00993  ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 91        ┆ 16.003972 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Filter cells that are > 140km from the nearest radar

# %%
DATA_CLOSE_TO_RADARS = DATA.filter(pl.col("dist_from_radars.min") < 140)

DATA_CLOSE_TO_RADARS
# Out:
# shape: (464_384, 82)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ identifie ┆ area_km2  ┆ method    ┆ timestamp ┆ … ┆ zdrcol_cu ┆ zdrcol_cu ┆ zdrcol_cu ┆ zdrcol_c │
# │ r         ┆ ---       ┆ ---       ┆ ---       ┆   ┆ stom_filt ┆ stom_filt ┆ stom_filt ┆ ustom_fi │
# │ ---       ┆ f64       ┆ str       ┆ datetime[ ┆   ┆ .max      ┆ .median   ┆ .count    ┆ lt.mean  │
# │ i64       ┆           ┆           ┆ μs]       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ 10.002483 ┆ opencv_vi ┆ 2021-05-0 ┆ … ┆ 800.0     ┆ 800.0     ┆ 12.0      ┆ 800.0    │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 11:35:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 14.003476 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 04:55:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 13.503352 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 05:00:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 14.003476 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 07:20:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 15.003724 ┆ opencv_vi ┆ 2023-05-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 07:25:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 79        ┆ 98.524454 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 80        ┆ 92.02284  ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ 2200.0    ┆ 800.0     ┆ 11.0      ┆ 1327.272 │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆ 727      │
# │           ┆           ┆ Area_10:c ┆ 14:00:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 80        ┆ 118.52941 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ 1800.0    ┆ 1400.0    ┆ 10.0      ┆ 1380.0   │
# │           ┆ 9         ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:05:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 80        ┆ 10.502607 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 83        ┆ 34.008441 ┆ opencv_vi ┆ 2021-06-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ l_1.0:min ┆ 9         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Area_10:c ┆ 14:40:00  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ lus…      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
from pprint import pprint

# zdrcol_thresholds = np.arange(800, 2000 + 1, 200)
# et45ml_thresholds = np.arange(0, 2000 + 1, 200)
zdrcol_thresholds = [
    1000,
]
et45ml_thresholds = [
    1000,
]

stats = ["median"]
zdrcol_quantities = [
    "zdrcol_custom_filt_unique_d1",
]
et45ml_quantities = [
    "et45ml_unique_d1",
]


# variables = {"zdrcol": "zdrcol_custom_filt.median", "et45ml": "et45ml.median"}

variables = {}
variables["zdrcol"] = {}
for q in zdrcol_quantities:
    for s in stats:
        variables["zdrcol"][f"{q}.{s}"] = f"{q}.{s}"

variables["et45ml"] = {}
for q in et45ml_quantities:
    for s in stats:
        variables["et45ml"][f"{q}.{s}"] = f"{q}.{s}"


conditions_conf_zdrcol = {}
for var, var_quantities in variables["zdrcol"].items():
    conditions_conf_zdrcol.update(
        {
            f"{var}:{thresh}": {
                var: {
                    "min": thresh,
                },
                "dist_from_radars.min": {"max": 140.0},
            }
            for thresh in zdrcol_thresholds
        }
    )

# Create conditions for et45ml
conditions_conf_et45ml = {}
for var, var_quantities in variables["et45ml"].items():
    conditions_conf_et45ml.update(
        {
            f"{var}:{thresh}": {
                var: {
                    "min": thresh,
                },
                "dist_from_radars.min": {"max": 140.0},
            }
            for thresh in et45ml_thresholds
        }
    )


condition_conf = {**conditions_conf_zdrcol, **conditions_conf_et45ml}
pprint(condition_conf)
# Out:
# {'et45ml_unique_d1.median:1000': {'dist_from_radars.min': {'max': 140.0},
#                                   'et45ml_unique_d1.median': {'min': 1000}},
#  'zdrcol_custom_filt_unique_d1.median:1000': {'dist_from_radars.min': {'max': 140.0},
#                                               'zdrcol_custom_filt_unique_d1.median': {'min': 1000}}}

# %% [markdown]
# # Calculate describe statistics for each group for each cell size interval

# %%
cell_area_bins = np.arange(10, 101, 10)  # 10, 20, ..., 100 km2

filtering_conditions = {}

lower_p = "5%"
upper_p = "90%"
round_decimals = 2

for cond_name, cond in condition_conf.items():
    print(f"Processing condition: {cond_name}")

    # Filter trajectories based on the condition
    datafilter = graph_utils.build_filter_from_conditions(cond)
    filtered_data = DATA.filter(pl.all_horizontal(datafilter)).to_pandas()

    # Group by area bins
    area_groups = filtered_data.groupby(
        pd.cut(filtered_data["area_km2"], bins=cell_area_bins, right=False, include_lowest=True), observed=True
    )
    filtering_conditions[cond_name] = condition_conf[cond_name]
    filtering_conditions[f"{cond_name}:control"] = {}

    for area_bin, group in area_groups:

        stats = group.describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])[
            ["area_km2", "rate.median", "rate.mean", "vil.median", "vil.mean"]
        ]

        pprint(f"Statistics for condition '{cond_name}' in area bin {area_bin}:")
        pprint(stats)

        # Store the statistics in the filtering_conditions dictionary
        filtering_conditions[f"{cond_name}:control"][f"area_{area_bin.left}_{area_bin.right}"] = {
            "area": {
                "min": area_bin.left.item(),
                "max": area_bin.right.item(),
            },
            "rate.mean": {
                "min": np.round(stats["rate.mean"].loc[lower_p], round_decimals).item(),
                "max": np.round(stats["rate.mean"].loc[upper_p], round_decimals).item(),
            },
            "dist_from_radars.min": {"max": 140.0},
            f"{cond_name.split(':')[0]}": {"isnull": True},
        }
# Out:
# Processing condition: zdrcol_custom_filt_unique_d1.median:1000
# ("Statistics for condition 'zdrcol_custom_filt_unique_d1.median:1000' in area "
#  'bin [10, 20):')
#            area_km2   rate.median     rate.mean    vil.median      vil.mean
# count  19502.000000  19502.000000  19502.000000  19502.000000  19502.000000
# mean      14.401046     17.031738     19.970284      1.730976      1.985943
# min       10.002483      0.720000      0.809000      1.000000      1.000000
#           area_km2  rate.median    rate.mean   vil.median     vil.mean
# count  4522.000000  4522.000000  4522.000000  4522.000000  4522.000000
# mean     84.715631    17.752811    26.789877     2.262218     3.188289
# min      80.019861     1.645000     2.182678     1.000000     1.158163
# 1%       80.019861     6.194201     8.368911     1.000000     1.403932
# 5%       80.519985     8.849155    12.910538     1.500000     1.688125
# 10%      80.519985    10.241000    15.047616     1.500000     1.895024
# 25%      82.020358    12.928809    19.639249     1.750000     2.321865
# 50%      84.520978    16.257500    25.686197     2.000000     2.982847
# 75%      87.021599    21.150001    32.881657     2.500000     3.814433
# 90%      89.022095    26.857618    39.992505     3.000000     4.802804
# 95%      89.522219    31.000000    44.331337     3.500000     5.470297
# 99%      89.522219    42.713287    54.597148     4.500000     6.757033
# max      89.522219   110.430473    82.469321     6.500000     8.545000
# std       2.896622     7.498937     9.894441     0.718108     1.172652
# "Statistics for condition 'et45ml_unique_d1.median:1000' in area bin [90, 100):"
#           area_km2  rate.median    rate.mean   vil.median     vil.mean
# count  3952.000000  3952.000000  3952.000000  3952.000000  3952.000000
# mean     94.724675    17.659253    26.844636     2.282325     3.247381
# min      90.022344     1.975000     2.605323     1.000000     1.181416
# 1%       90.022344     6.464264     9.066700     1.000000     1.432131
# 5%       90.522468     8.840000    12.890404     1.500000     1.738646
# 10%      90.522468    10.260000    15.317334     1.500000     1.927102
# 25%      92.522964    12.928809    19.677520     2.000000     2.361541
# 50%      94.523461    16.250000    25.782321     2.000000     3.002119
# 75%      97.024081    20.961249    32.881198     2.500000     3.899342
# 90%      98.524454    26.545999    39.624989     3.000000     4.883929
# 95%      99.024578    31.000000    44.504864     3.500000     5.672617
# 99%      99.524702    41.236679    54.501209     4.500000     7.127274
# max      99.524702    67.593498    74.328776     6.250000     9.650485
# std       2.863208     7.060288     9.747922     0.725535     1.219502

# %%
print(f"Number of conditions: {len(filtering_conditions)}")
# Out:
# Number of conditions: 4

# %%
import yaml

print(yaml.dump(filtering_conditions, default_flow_style=False))

outfile = Path(
    "/home/users/ritvanen/koodaus/rain-cell-stats-analysis/config/plots/swiss-data/filtering_conditions_v20250814.yaml"
)
with open(outfile, "w") as f:
    yaml.dump(filtering_conditions, f, default_flow_style=False)
# Out:
# et45ml_unique_d1.median:1000:
#   dist_from_radars.min:
#     max: 140.0
#   et45ml_unique_d1.median:
#     min: 1000
# et45ml_unique_d1.median:1000:control:
#   area_10_20:
#     area:
#       max: 20
#       min: 10
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 41.96
#       min: 10.26
#   area_20_30:
#     area:
#       max: 30
#       min: 20
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 41.12
#       min: 10.76
#   area_30_40:
#     area:
#       max: 40
#       min: 30
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 40.62
#       min: 11.31
#   area_40_50:
#     area:
#       max: 50
#       min: 40
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 41.06
#       min: 12.02
#   area_50_60:
#     area:
#       max: 60
#       min: 50
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 40.22
#       min: 11.94
#   area_60_70:
#     area:
#       max: 70
#       min: 60
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 39.95
#       min: 12.36
#   area_70_80:
#     area:
#       max: 80
#       min: 70
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 40.76
#       min: 12.53
#   area_80_90:
#     area:
#       max: 90
#       min: 80
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 39.99
#       min: 12.91
#   area_90_100:
#     area:
#       max: 100
#       min: 90
#     dist_from_radars.min:
#       max: 140.0
#     et45ml_unique_d1.median:
#       isnull: true
#     rate.mean:
#       max: 39.62
#       min: 12.89
# zdrcol_custom_filt_unique_d1.median:1000:
#   dist_from_radars.min:
#     max: 140.0
#   zdrcol_custom_filt_unique_d1.median:
#     min: 1000
# zdrcol_custom_filt_unique_d1.median:1000:control:
#   area_10_20:
#     area:
#       max: 20
#       min: 10
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 33.04
#       min: 8.02
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_20_30:
#     area:
#       max: 30
#       min: 20
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 33.66
#       min: 8.48
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_30_40:
#     area:
#       max: 40
#       min: 30
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 34.15
#       min: 8.8
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_40_50:
#     area:
#       max: 50
#       min: 40
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 35.08
#       min: 9.13
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_50_60:
#     area:
#       max: 60
#       min: 50
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 34.94
#       min: 9.27
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_60_70:
#     area:
#       max: 70
#       min: 60
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 34.93
#       min: 9.67
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_70_80:
#     area:
#       max: 80
#       min: 70
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 35.66
#       min: 9.5
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_80_90:
#     area:
#       max: 90
#       min: 80
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 35.74
#       min: 9.82
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
#   area_90_100:
#     area:
#       max: 100
#       min: 90
#     dist_from_radars.min:
#       max: 140.0
#     rate.mean:
#       max: 35.5
#       min: 10.08
#     zdrcol_custom_filt_unique_d1.median:
#       isnull: true
